# %% [markdown]
# ### Feature Extraction

# %%
#importing librbares
import pandas as pd
import numpy as np

# %%
# reading csv

df=pd.read_csv('retail_customer.csv')
df.head()
# Out:
#                             customer_id           name  age  gender  \
# 0  5c7825f3-13bb-4843-9cf1-5b7a944def13  Andrew Miller   56    Male
# 1  ad1cf2e3-be49-4031-9770-c308b2d1292c    Kevin Ramos   69   Other
# 2  33194def-ebb0-4d75-8942-9c83d7d579f2     John Smith   46   Other
# 3  6a1ce340-ec27-482e-a339-e89e2db11a01   Dustin Nolan   32    Male
# 4  3e529d86-76ed-4c85-83cf-c5ab446cb3c0    Amy Johnson   60  Female
#
#   signup_date last_purchase_date  total_purchases  total_spent  \
# 0  2025-01-01         2024-06-12               18      6143.01
# 1  2025-05-16         2024-10-03               86      9498.14
# 2  2025-04-15         2025-04-27               34      4026.83
# 3  2023-10-10         2024-10-20                8      9545.46
# 4  2024-02-02         2025-03-03               40      1436.51
#
#               country                      email device_type  is_subscribed  \
# 0          Bangladesh        qwilson@example.org      Mobile              1
# 1             Eritrea          shall@example.net      Mobile              1
# 2  Russian Federation       leebrian@example.org      Mobile              0
# 3              Serbia        sguzman@example.org      Mobile              1
# 4           Mauritius  griffithsarah@example.org      Mobile              1
#
#    feedback_score
# 0             2.7
# 1             1.6
# 2             3.7
# 3             1.9
# 4             1.4

# %%
df.shape
# Out:
# (500, 13)

# %%
df.dtypes
# Out:
# customer_id            object
# name                   object
# age                     int64
# gender                 object
# signup_date            object
# last_purchase_date     object
# total_purchases         int64
# total_spent           float64
# country                object
# email                  object
# device_type            object
# is_subscribed           int64
# feedback_score        float64
# dtype: object

# %%
# binning age into categories

bins=[10, 30, 50, 70]  # age ranges
labels=["Young","Mid","Seniors"] # categories
df["age_group"] =pd.cut(df["age"],bins=bins, labels=labels) #cut creates equal size of bins

# Displaying the first few rows
df[['age','age_group']].head(10)
# Out:
#    age age_group
# 0   56   Seniors
# 1   69   Seniors
# 2   46       Mid
# 3   32       Mid
# 4   60   Seniors
# 5   25     Young
# 6   38       Mid
# 7   56   Seniors
# 8   36       Mid
# 9   40       Mid

# %%
# converting dates cloumns to datetime

df['signup_date']=pd.to_datetime(df['signup_date'])
df['last_purchase_date']=pd.to_datetime(df['last_purchase_date'])

# %%
df.dtypes
# Out:
# customer_id                   object
# name                          object
# age                            int64
# gender                        object
# signup_date           datetime64[ns]
# last_purchase_date    datetime64[ns]
# total_purchases                int64
# total_spent                  float64
# country                       object
# email                         object
# device_type                   object
# is_subscribed                  int64
# feedback_score               float64
# age_group                   category
# dtype: object

# %%
# Extract Time based features
df['signup_year']=df['signup_date'].dt.year  #.dt function for extracting year/month/week/day
df['signup_month']=df['signup_date'].dt.month
df['days_since_signup']=(pd.Timestamp.today()-df['signup_date']).dt.days

df['days_since_last_purchase']=(pd.Timestamp.today() - df['last_purchase_date']).dt.days

# %%
# name features
df['first_name']=df['name'].apply(lambda x:x.split()[0])
df['last_name']=df['name'].apply(lambda x: x.split()[-1])
df['name_length']=df['name'].apply(len)

# %%
# High spender flag

df['is_high_spender'] =(df['total_spent']>5000).astype(int)

# %%
df
# Out:
#                               customer_id            name  age  gender  \
# 0    5c7825f3-13bb-4843-9cf1-5b7a944def13   Andrew Miller   56    Male
# 1    ad1cf2e3-be49-4031-9770-c308b2d1292c     Kevin Ramos   69   Other
# 2    33194def-ebb0-4d75-8942-9c83d7d579f2      John Smith   46   Other
# 3    6a1ce340-ec27-482e-a339-e89e2db11a01    Dustin Nolan   32    Male
# 4    3e529d86-76ed-4c85-83cf-c5ab446cb3c0     Amy Johnson   60  Female
# ..                                    ...             ...  ...     ...
# 495  cae07587-71ec-4ad9-95d3-1733b04039f6   Natalie Clark   65    Male
# 496  91c6672b-6ace-4367-9e31-8bd1d8fea975  Jennifer Jones   42    Male
# 497  9521ecfa-af06-4865-9a4b-e70827ba2485     Jeremy Luna   57    Male
# 498  28da13d6-c253-4279-b3aa-e41599598e9f   Leah Williams   62  Female
# 499  25992e78-ad4c-4ca9-9cd3-81a023832ed2    Wayne Rivera   18   Other
#
#     signup_date last_purchase_date  total_purchases  total_spent  \
# 0    2025-01-01         2024-06-12               18      6143.01
# 1    2025-05-16         2024-10-03               86      9498.14
# 2    2025-04-15         2025-04-27               34      4026.83
# 3    2023-10-10         2024-10-20                8      9545.46
# 4    2024-02-02         2025-03-03               40      1436.51
# ..          ...                ...              ...          ...
# 495  2024-04-12         2023-09-30               40      3550.88
# 496  2024-07-18         2023-10-23               11      1676.95
# 497  2025-04-20         2023-10-27               36      6089.04
# 498  2022-06-20         2024-08-20               59      3249.30
# 499  2024-09-27         2025-04-14               39      8677.74
#
#                     country                      email  ... feedback_score  \
# 0                Bangladesh        qwilson@example.org  ...            2.7
# 1                   Eritrea          shall@example.net  ...            1.6
# 2        Russian Federation       leebrian@example.org  ...            3.7
# 3                    Serbia        sguzman@example.org  ...            1.9
# 4                 Mauritius  griffithsarah@example.org  ...            1.4
# ..                      ...                        ...  ...            ...
# 495        Christmas Island   coxelizabeth@example.com  ...            2.1
# 496                 Vanuatu    curtisjesse@example.org  ...            3.7
# 497                   Nauru        uwalker@example.org  ...            1.1
# 498  British Virgin Islands     perryjacob@example.com  ...            2.2
# 499    United Arab Emirates     lyonsbarry@example.net  ...            3.2
#
#      age_group  signup_year signup_month  days_since_signup  \
# 0      Seniors         2025            1                365
# 1      Seniors         2025            5                230
# 2          Mid         2025            4                261
# 3          Mid         2023           10                814
# 4      Seniors         2024            2                699
# ..         ...          ...          ...                ...
# 495    Seniors         2024            4                629
# 496        Mid         2024            7                532
# 497    Seniors         2025            4                256
# 498    Seniors         2022            6               1291
# 499      Young         2024            9                461
#
#      days_since_last_purchase  first_name  last_name name_length  \
# 0                         568      Andrew     Miller          13
# 1                         455       Kevin      Ramos          11
# 2                         249        John      Smith          10
# 3                         438      Dustin      Nolan          12
# 4                         304         Amy    Johnson          11
# ..                        ...         ...        ...         ...
# 495                       824     Natalie      Clark          13
# 496                       801    Jennifer      Jones          14
# 497                       797      Jeremy       Luna          11
# 498                       499        Leah   Williams          13
# 499                       262       Wayne     Rivera          12
#
#     is_high_spender
# 0                 1
# 1                 1
# 2                 0
# 3                 1
# 4                 0
# ..              ...
# 495               0
# 496               0
# 497               1
# 498               0
# 499               1
#
# [500 rows x 22 columns]

# %%
# low spender 

df['is_low_spender']=(df['total_spent']<1000).astype(int)

# %%
df
# Out:
#                               customer_id            name  age  gender  \
# 0    5c7825f3-13bb-4843-9cf1-5b7a944def13   Andrew Miller   56    Male
# 1    ad1cf2e3-be49-4031-9770-c308b2d1292c     Kevin Ramos   69   Other
# 2    33194def-ebb0-4d75-8942-9c83d7d579f2      John Smith   46   Other
# 3    6a1ce340-ec27-482e-a339-e89e2db11a01    Dustin Nolan   32    Male
# 4    3e529d86-76ed-4c85-83cf-c5ab446cb3c0     Amy Johnson   60  Female
# ..                                    ...             ...  ...     ...
# 495  cae07587-71ec-4ad9-95d3-1733b04039f6   Natalie Clark   65    Male
# 496  91c6672b-6ace-4367-9e31-8bd1d8fea975  Jennifer Jones   42    Male
# 497  9521ecfa-af06-4865-9a4b-e70827ba2485     Jeremy Luna   57    Male
# 498  28da13d6-c253-4279-b3aa-e41599598e9f   Leah Williams   62  Female
# 499  25992e78-ad4c-4ca9-9cd3-81a023832ed2    Wayne Rivera   18   Other
#
#     signup_date last_purchase_date  total_purchases  total_spent  \
# 0    2025-01-01         2024-06-12               18      6143.01
# 1    2025-05-16         2024-10-03               86      9498.14
# 2    2025-04-15         2025-04-27               34      4026.83
# 3    2023-10-10         2024-10-20                8      9545.46
# 4    2024-02-02         2025-03-03               40      1436.51
# ..          ...                ...              ...          ...
# 495  2024-04-12         2023-09-30               40      3550.88
# 496  2024-07-18         2023-10-23               11      1676.95
# 497  2025-04-20         2023-10-27               36      6089.04
# 498  2022-06-20         2024-08-20               59      3249.30
# 499  2024-09-27         2025-04-14               39      8677.74
#
#                     country                      email  ... signup_year  \
# 0                Bangladesh        qwilson@example.org  ...        2025
# 1                   Eritrea          shall@example.net  ...        2025
# 2        Russian Federation       leebrian@example.org  ...        2025
# 3                    Serbia        sguzman@example.org  ...        2023
# 4                 Mauritius  griffithsarah@example.org  ...        2024
# ..                      ...                        ...  ...         ...
# 495        Christmas Island   coxelizabeth@example.com  ...        2024
# 496                 Vanuatu    curtisjesse@example.org  ...        2024
# 497                   Nauru        uwalker@example.org  ...        2025
# 498  British Virgin Islands     perryjacob@example.com  ...        2022
# 499    United Arab Emirates     lyonsbarry@example.net  ...        2024
#
#      signup_month  days_since_signup days_since_last_purchase  first_name  \
# 0               1                365                      568      Andrew
# 1               5                230                      455       Kevin
# 2               4                261                      249        John
# 3              10                814                      438      Dustin
# 4               2                699                      304         Amy
# ..            ...                ...                      ...         ...
# 495             4                629                      824     Natalie
# 496             7                532                      801    Jennifer
# 497             4                256                      797      Jeremy
# 498             6               1291                      499        Leah
# 499             9                461                      262       Wayne
#
#      last_name  name_length  is_high_spender low_spender is_low_spender
# 0       Miller           13                1           0              0
# 1        Ramos           11                1           0              0
# 2        Smith           10                0           0              0
# 3        Nolan           12                1           0              0
# 4      Johnson           11                0           0              0
# ..         ...          ...              ...         ...            ...
# 495      Clark           13                0           0              0
# 496      Jones           14                0           0              0
# 497       Luna           11                1           0              0
# 498   Williams           13                0           0              0
# 499     Rivera           12                1           0              0
#
# [500 rows x 24 columns]

# %%
df[['is_high_spender','is_low_spender']].head(10)
# Out:
#    is_high_spender  is_low_spender
# 0                1               0
# 1                1               0
# 2                0               0
# 3                1               0
# 4                0               0
# 5                0               0
# 6                0               0
# 7                1               0
# 8                0               0
# 9                1               0
